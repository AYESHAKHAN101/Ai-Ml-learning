# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
#pd.set_option('max_columns, 200')

# %%
import pandas as pd

pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 500)

# %%
df=pd.read_csv('coaster_db - coaster_db.csv')

# %%
df
# Out:
#                                 coaster_name                Length                    Speed                        Location              Status   Opening date                                  Type                 Manufacturer Height restriction                     Model            Height  Inversions        Lift/launch system Cost                                             Trains               Park section Duration               Capacity G-force                  Designer Max vertical angle  \
# 0                         Switchback Railway        600 ft (180 m)         6 mph (9.7 km/h)                    Coney Island             Removed  June 16, 1884                                  Wood       LaMarcus Adna Thompson                NaN               Lift Packed      50 ft (15 m)         NaN                   gravity  NaN                                                NaN  Coney Island Cyclone Site     1:00   1600 riders per hour     2.9    LaMarcus Adna Thompson                30°
# ...

# %%
'''Step1:Data Understanding
1.Dataframe shape
2. head and tail
3.dtypes
4.describe
'''
# Out:
# 'Step1:Data Understanding\n1.Dataframe shape\n2. head and tail\n3.dtypes\n4.describe\n'

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.head()
# Out:
#                              coaster_name          Length             Speed                        Location   Status   Opening date   Type            Manufacturer Height restriction        Model        Height  Inversions Lift/launch system Cost                                             Trains               Park section Duration              Capacity G-force                Designer Max vertical angle          Drop Soft opening date Fast Lane available            Replaced  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)                    Coney Island  Removed  June 16, 1884   Wood  LaMarcus Adna Thompson                NaN  Lift Packed  50 ft (15 m)         NaN            gravity  NaN                                                NaN  Coney Island Cyclone Site     1:00  1600 riders per hour     2.9  LaMarcus Adna Thompson                30°  43 ft (13 m)               NaN                 NaN                 NaN
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value   speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  932.000000      1087.000000  812.000000  812.000000    937.000000  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374   48.617289     89.575171  101.996491          1.326587      3.824006
# std      2.114073        23.475248   15.516596   72.285227     23.385518   16.678031    136.246444   67.329092          2.030854      0.989998
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000    5.000000      4.000000   13.100000          0.000000      0.800000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000   37.300000     44.000000   51.800000          0.000000      3.400000
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
'''Step2:Data Preperation
-Dropping irrevelent columns and rows
-Identifying duplicate columns
-Renaming Columns
-Feature Creations'''
# Out:
# 'Step2:Data Preperation\n-Dropping irrevelent columns and rows\n-Identifying duplicate columns\n-Renaming Columns\n-Feature Creations'

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date', 'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height', 'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section', 'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle', 'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced', 'Track layout', 'Fastrack available', 'Soft opening date.1', 'Closing date', 'Opened', 'Replaced by', 'Website', 'Flash Pass Available',
#        'Must transfer from wheelchair', 'Theme', 'Single rider line available', 'Restraint Style', 'Flash Pass available', 'Acceleration', 'Restraints', 'Name', 'year_introduced', 'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit', 'speed_mph', 'height_value', 'height_unit', 'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
#df.drop(['Opening Date',axis=1])

# %%
df= df [['coaster_name','Location', 'Status', 'Manufacturer','year_introduced', 'latitude', 'longitude', 'Type_Main', 'opening_date_clean','speed_mph','height_ft', 'Inversions_clean', 'Gforce_clean']]

# %%
df
# Out:
#                                 coaster_name                        Location              Status                 Manufacturer  year_introduced  latitude  longitude Type_Main opening_date_clean  speed_mph  height_ft  Inversions_clean  Gforce_clean
# 0                         Switchback Railway                    Coney Island             Removed       LaMarcus Adna Thompson             1884   40.5740   -73.9780      Wood         1884-06-16        6.0        NaN                 0           2.9
# 1                          Flip Flap Railway                   Sea Lion Park             Removed                 Lina Beecher             1895   40.5780   -73.9790      Wood         1895-01-01        NaN        NaN                 1          12.0
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States              Closed                          NaN             1896   41.5800   -81.5700     Other                NaN        NaN        NaN                 0           NaN
# ...

# %%
df.shape
# Out:
# (1087, 13)

# %%
df['opening_date_clean']
# Out:
# 0       1884-06-16
# 1       1895-01-01
# 2              NaN
# 3       1901-01-01
# 4       1901-01-01
#            ...
# 1082           NaN
# 1083    2022-01-01
# 1084    2016-06-16
# 1085           NaN
# 1086    2022-01-01
# Name: opening_date_clean, Length: 1087, dtype: object

# %%
import pandas as pd
df['opening_date_clean']=pd.to_datetime(df['opening_date_clean'])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12164\1110906309.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['opening_date_clean']=pd.to_datetime(df['opening_date_clean'])

# %%
df.columns
# Out:
# Index(['coaster_name', 'Location', 'Status', 'Manufacturer', 'year_introduced', 'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph', 'height_ft', 'Inversions_clean', 'Gforce_clean'], dtype='object')

# %%
#Renaming
df=df.rename(columns={'opening_date_clean': 'opening_date',
                   'Inversions_clean': 'Inversions',
                    'Type_Main': 'Type',
                     'Gforce_clean' : 'Gforce',
                     'height_ft':'height'
                    })

# %%
df
# Out:
#                                 coaster_name                        Location              Status                 Manufacturer  year_introduced  latitude  longitude   Type opening_date  speed_mph  height  Inversions  Gforce
# 0                         Switchback Railway                    Coney Island             Removed       LaMarcus Adna Thompson             1884   40.5740   -73.9780   Wood   1884-06-16        6.0     NaN           0     2.9
# 1                          Flip Flap Railway                   Sea Lion Park             Removed                 Lina Beecher             1895   40.5780   -73.9790   Wood   1895-01-01        NaN     NaN           1    12.0
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States              Closed                          NaN             1896   41.5800   -81.5700  Other          NaT        NaN     NaN           0     NaN
# ...

# %%
df.isna().sum()
# Out:
# coaster_name         0
# Location             0
# Status             213
# Manufacturer        59
# year_introduced      0
# latitude           275
# longitude          275
# Type                 0
# opening_date       250
# speed_mph          150
# height             916
# Inversions           0
# Gforce             725
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082    False
# 1083    False
# 1084    False
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [coaster_name, Location, Status, Manufacturer, year_introduced, latitude, longitude, Type, opening_date, speed_mph, height, Inversions, Gforce]
# Index: []

# %%
df.loc[df.duplicated(subset=['coaster_name'])]
# Out:
#                                          coaster_name                         Location              Status                                       Manufacturer  year_introduced  latitude  longitude   Type opening_date  speed_mph  height  Inversions  Gforce
# 43                              Crystal Beach Cyclone               Crystal Beach Park             Removed                                 Traver Engineering             1927   42.8617   -79.0598   Wood   1926-01-01       60.0     NaN           0     4.0
# 60                                        Derby Racer                     Revere Beach             Removed                                     Fred W. Pearce             1937   42.4200   -70.9860   Wood   1911-01-01        NaN     NaN           0     NaN
# ...

# %% [markdown]
# #Checking on exapmle duplication

# %%
#Checking on exapmle duplication
df.query('coaster_name == "Crystal Beach Cyclone"')
# Out:
#              coaster_name            Location   Status        Manufacturer  year_introduced  latitude  longitude  Type opening_date  speed_mph  height  Inversions  Gforce
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering             1926   42.8617   -79.0598  Wood   1926-01-01       60.0     NaN           0     4.0
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering             1927   42.8617   -79.0598  Wood   1926-01-01       60.0     NaN           0     4.0

# %%
df.query('coaster_name == "Flashback (Six Flags Magic Mountain)	"')
# Out:
# Empty DataFrame
# Columns: [coaster_name, Location, Status, Manufacturer, year_introduced, latitude, longitude, Type, opening_date, speed_mph, height, Inversions, Gforce]
# Index: []

# %%
df= df.loc[~df.duplicated(subset=['coaster_name','Location','opening_date'])].reset_index(drop=True).copy()

# %%
df
# Out:
#                                coaster_name                        Location              Status                 Manufacturer  year_introduced  latitude  longitude   Type opening_date  speed_mph  height  Inversions  Gforce
# 0                        Switchback Railway                    Coney Island             Removed       LaMarcus Adna Thompson             1884   40.5740   -73.9780   Wood   1884-06-16        6.0     NaN           0     2.9
# 1                         Flip Flap Railway                   Sea Lion Park             Removed                 Lina Beecher             1895   40.5780   -73.9790   Wood   1895-01-01        NaN     NaN           1    12.0
# 2    Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States              Closed                          NaN             1896   41.5800   -81.5700  Other          NaT        NaN     NaN           0     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   coaster_name     990 non-null    object
#  1   Location         990 non-null    object
#  2   Status           844 non-null    object
#  3   Manufacturer     932 non-null    object
#  4   year_introduced  990 non-null    int64
#  5   latitude         783 non-null    float64
#  6   longitude        783 non-null    float64
#  7   Type             990 non-null    object
#  8   opening_date     807 non-null    datetime64[ns]
#  9   speed_mph        850 non-null    float64
#  10  height           159 non-null    float64
#  11  Inversions       990 non-null    int64
#  12  Gforce           324 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 100.7+ KB

# %%
df.isna().sum()
# Out:
# coaster_name         0
# Location             0
# Status             146
# Manufacturer        58
# year_introduced      0
# latitude           207
# longitude          207
# Type                 0
# opening_date       183
# speed_mph          140
# height             831
# Inversions           0
# Gforce             666
# dtype: int64

# %% [markdown]
# # Step3 Feature understanding (univariate analysis)
# - plotting feature Distributiion
# - Histogram
# - KDE
# - Box

# %%
df.columns
# Out:
# Index(['coaster_name', 'Location', 'Status', 'Manufacturer', 'year_introduced', 'latitude', 'longitude', 'Type', 'opening_date', 'speed_mph', 'height', 'Inversions', 'Gforce'], dtype='object')

# %%
df['year_introduced'].value_counts()
# Out:
# year_introduced
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
# 2008    27
# 2004    25
# 2007    24
# 2011    24
# 2006    23
# 2012    23
# 2013    23
# 1996    23
# 2014    22
# 1995    22
# 2015    22
# 2003    21
# 2009    21
# 1997    21
# 2005    20
# 2019    19
# 2010    19
# 2018    18
# 1992    17
# 2016    17
# 2017    17
# 1976    16
# 1994    16
# 1985    15
# 1993    14
# 1988    14
# 1987    13
# 1991    13
# 1989    13
# 1990    13
# 1984    13
# 1978    12
# 2022    12
# 2021    12
# 1983    11
# 1981    11
# 2020    10
# 1979     9
# 1980     8
# 1975     7
# 1972     7
# 1982     7
# 1925     6
# 1927     6
# 1977     6
# 1986     5
# 1924     5
# 1974     5
# 1970     4
# 1920     3
# 1926     3
# 1969     3
# 1971     3
# 1966     3
# 1964     3
# 1958     3
# 1973     3
# 1951     3
# 1950     2
# 1923     2
# 1901     2
# 1941     2
# 1946     2
# 1902     2
# 1907     2
# 1913     2
# 1909     2
# 1928     2
# 1940     2
# 1912     2
# ...

# %% [markdown]
# #top 10 year

# %%
ax = df['year_introduced'].value_counts().head(10)

# %%
ax
# Out:
# year_introduced
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
# 2008    27
# 2004    25
# 2007    24
# 2011    24
# 2006    23
# Name: count, dtype: int64

# %%
#DAta intensity in bar
ax.plot(kind='bar', title="Top 10 year Coasters Introduction", xlabel('Year Introduced'))

ax.ylabel('Count')
# Out:
#   Cell In[41], line 2
#     ax.plot(kind='bar', title="Top 10 year Coasters Introduction", xlabel('Year Introduced'))
#                                                                                             ^
# SyntaxError: positional argument follows keyword argument

# %%
#on y-axis we have frequency(no. of coaster in speed) but on x-axis(speed_mph)?
#we need to find what we have on x-axis?
#bins(grouping)
#hist how namy colunms on each ranges bins divide ranges
ax = df['speed_mph'].plot(kind='hist', title='Coaster Speed (mph)')

# %%
df['speed_mph'].unique()
# Out:
# array([  6. ,   nan,  10. ,  40. ,  37.3,  53. ,  45. ,  42. ,  35. ,
#         50. ,  55. ,  32. ,  48. ,  60. ,  31. ,  58. ,  25. ,  49.7,
#         27. ,  29. ,  14. ,  44.7,  31.1,  37. ,  46. ,  30. ,  57. ,
#         56. ,  36. ,   5. ,  62. ,  32.9,  64.8,  46.6,  41. ,  66. ,
#         34. ,  52. ,  34.8,  16.2,  55.9,  39.8,  51. ,  43.5,  40.4,
#         54.1,  17. ,  28. ,  47. ,  16.8,  34.1,  22.4,  59.7,  29.8,
#         47.8,  44. ,  68.3,  28.9,  65. ,  54.5,  68. ,  72. ,  54.7,
#         23. ,  24.9,  70. ,  34.2,  85. ,  35.4,  15. ,  56.5,  62.1,
#         21.7,  18.6,  80. ,  48.5,  66.5,  50.3,  74. ,  71.5,  52.4,
#         52.8,  43. ,  50.2,  54. ,  81. ,  33. ,  27.7,  75. ,  67. ,
#         63. , 100. ,  68.4,  50.5,   8. ,  73. ,  61. ,  29.1,  11. ,
#         16. ,  76. ,  41.2,  64. ,  66.3,  28.5,  59. ,  93. ,  78.4,
#         95. ,  77. ,  57.2,  13. ,  65.6, 111.8,  74.6,  26. ,  53.4,
# ...

# %%
#on y-axis we have frequency(no. of coaster in speed) but on x-axis(speed_mph)?
#we need to find what we have on x-axis?
#bins(grouping)
#hist how namy colunms on each ranges bins divide ranges
ax = df['speed_mph'].plot(kind='hist', bins=20,title='Coaster Speed (mph)')

# %%
#df[df['speed_mph']<=20].count()

# %%
df.isna().sum()
# Out:
# coaster_name         0
# Location             0
# Status             146
# Manufacturer        58
# year_introduced      0
# latitude           207
# longitude          207
# Type                 0
# opening_date       183
# speed_mph          140
# height             831
# Inversions           0
# Gforce             666
# dtype: int64

# %%
ax = df['speed_mph'].plot(kind='kde', title='Coaster Speed (mph)')

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df['coaster_name'].unique()
# Out:
# array(['Switchback Railway', 'Flip Flap Railway',
#        'Switchback Railway (Euclid Beach Park)',
#        'Loop the Loop (Coney Island)', "Loop the Loop (Young's Pier)",
#        'Cannon Coaster', 'Leap-The-Dips',
#        'Figure Eight (Euclid Beach Park)', 'Drop the Dip',
#        'Scenic Railway (Euclid Beach Park)',
#        'Loop the Loop (Olentangy Park)', 'Aero Dips',
#        'Backety-Back Scenic Railway', 'Racer (1910 roller coaster)',
#        'Derby Racer', 'The Great Scenic Railway', 'Zippin Pippin',
#        'Racing Coaster', 'Whirl Pool Dips',
#        'Green Dragon (Lake Compounce)', 'The Wild One (roller coaster)',
#        'Jack Rabbit (Clementon Park)', 'Jack Rabbit (Kennywood)',
#        'Jack Rabbit (Seabreeze)', 'Scenic Railway (roller coaster)',
#        'Roller Coaster (Lagoon)', 'Big Dipper (Blackpool Pleasure Beach)',
#        'Wild Cat (Hersheypark)', 'The Bobs (roller coaster)',
#        'Giant Dipper', 'Pippin (roller coaster)',
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Location', 'Status', 'Manufacturer', 'year_introduced', 'latitude', 'longitude', 'Type', 'opening_date', 'speed_mph', 'height', 'Inversions', 'Gforce'], dtype='object')

# %%
df['coaster_name'].nunique()
# Out:
# 990

# %%
df['Type'].nunique()
# Out:
# 3

# %%
df['Type'].value_counts()
# Out:
# Type
# Steel    728
# Wood     191
# Other     71
# Name: count, dtype: int64

# %% [markdown]
# # Step 4. Feature Relationship

# %%
df.columns
# Out:
# Index(['coaster_name', 'Location', 'Status', 'Manufacturer', 'year_introduced', 'latitude', 'longitude', 'Type', 'opening_date', 'speed_mph', 'height', 'Inversions', 'Gforce'], dtype='object')

# %%
df.isna().sum()
# Out:
# coaster_name         0
# Location             0
# Status             146
# Manufacturer        58
# year_introduced      0
# latitude           207
# longitude          207
# Type                 0
# opening_date       183
# speed_mph          140
# height             831
# Inversions           0
# Gforce             666
# dtype: int64

# %%
df.Status.unique()
# Out:
# array(['Removed', 'Closed', 'Operating', nan, 'Not Currently Operating',
#        'In Production', 'Discontinued',
#        'closed for maintenance as of july 30 no reopening date known',
#        'Closed in 2021', 'SBNO December 2019', 'Under construction',
#        'Temporarily Closed', 'SBNO (Standing But Not Operating)',
#        'Temporarily closed',
#        'Chapter 7 bankruptcy; rides dismantled and sold; property sold',
#        'Under Maintenance'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   coaster_name     990 non-null    object
#  1   Location         990 non-null    object
#  2   Status           844 non-null    object
#  3   Manufacturer     932 non-null    object
#  4   year_introduced  990 non-null    int64
#  5   latitude         783 non-null    float64
#  6   longitude        783 non-null    float64
#  7   Type             990 non-null    object
#  8   opening_date     807 non-null    datetime64[ns]
#  9   speed_mph        850 non-null    float64
#  10  height           159 non-null    float64
#  11  Inversions       990 non-null    int64
#  12  Gforce           324 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 100.7+ KB

# %%
df.plot(kind='scatter',x='Location', y='speed_mph')

# %%
df.plot(kind='scatter',x='Type', y='speed_mph')
# Out:
# <Axes: xlabel='Type', ylabel='speed_mph'>

# %%
df.plot(kind='scatter',x='Gforce', y='height')
# Out:
# <Axes: xlabel='Gforce', ylabel='height'>

# %%
ax =sns.scatterplot(x='speed_mph',y='height', hue='year_introduced', data=df)

# %%
#plotly
ax =sns.scatterplot(x='speed_mph',y='height', hue='year_introduced', data=df)

# %%
#pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df.columns
# Out:
# Index(['coaster_name', 'Location', 'Status', 'Manufacturer', 'year_introduced', 'latitude', 'longitude', 'Type', 'opening_date', 'speed_mph', 'height', 'Inversions', 'Gforce'], dtype='object')

# %%
sns.pairplot(df, vars= ['year_introduced','speed_mph','height', 'Inversions', 'Gforce'],hue='Type')

# %%
#seabor me aap colour palets provide krtn hn. and season colour for u.
